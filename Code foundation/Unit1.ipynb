# %% [markdown]
# # Unit 1: Introduction to the Course

# %%
cd /home/user/catkin_ws/src

# %%
ls

# %%
python arm_control.py

# %%
from smart_grasping_sandbox.smart_grasper import SmartGrasper
# from msg.data import msg name
from tf.transformations import quaternion_from_euler
from math import pi
import time

sgs = SmartGrasper()

sgs.pick()

sgs.reset_world()

# %% [markdown]
#  You should see your Python program listed there. To execute the Python program, type:

# %%
python arm_control.py

# %% [markdown]
# Important things from the previous exercise:
#
# * Every Python program you create must follow the name convention **<𝑦𝑜𝑢𝑟−𝑝𝑟𝑜𝑔𝑟𝑎𝑚−𝑛𝑎𝑚𝑒>.py**
# * In order to execute a Python program, you must type:

# %% [markdown]
# # What will you learn with this course?
#
# In the code above, you have applied many of the Python concepts that you are going to learn in this coursep
#
# ```
# 1. to store data into variables
# 2. to operate with the data in the variables
# 3. to change behavior based on conditions
# 4. to create functions that can be called from other places of the code
# 5. to encapsulate the code into classes so you can have clean and robust code
# ```
