# %% [markdown]
# ```
# Object : data and function
# Class object;         Class object (data and function)
#
# Fruit mango;
#
# Encapsulation :   class1 object1;              Class1 object 2;
# ```

# %% [markdown]
# # **Unit 5: Python Classes & OOP**
#
# > 1. Introduction to Object-Oriented Programming (OOP)
# >
# > 2. How to use Classes in your python programs
#
# The organization method/principle used in Python is called **Object Oriented Programming** and it is based on the concept of **Python classes**.

# %% [markdown]
# # 1.Object-Oriented Programming
#
# 1. In all the programs we've written up until now, we have designed
# >  Our programs around functions, which manipulate data stored in variables. This is called the **procedure-oriented way of programming**.
#
# 2. **Object-oriented programming, or OOP** is based on **combining data and functionality, and wrapping them inside things** known as **objects** (also called classes).
# >  Code will be better organized and it will be much **easier to understand, debug, maintain, and upgrade.**

# %% [markdown]
# These **objects** are usually defined by two things:
#
# > * Attributes: This is the data associated with the object, defined in fields.
# > * Methods: These are the procedures or functions associated with the object.

# %% [markdown]
# ## What are Python classes?
#
#
# **A Python class is, basically, a code template for creating an object.**
#
# For example, the class *Jedi* below describes how to create an object of type Jedi,
# > so you can use that object of that type to store and manipulate data the way the class defines.
#
#  For example, if my code has created the class Jedi, then I can create an object of that type by doing:

# %%
# The object my_object is a variable of type *Jedi*.

my_object = Jedi("Qui-Gong-Jin")

# %% [markdown]
# > Remember, we already used that in previous chapters. For example:

# %%
rc = RobotControl()

# %% [markdown]
# We were creating a variable (or **object**) named *rc* of type *RobotControl.*
#
# * The difference between the **Jedi** class and the **RobotControl** class is that the former requires a parameter to build the object (requires the name of the Jedi), and the later requires no parameter to build the obejct.

# %% [markdown]
# **NOTE:** When we create a variable of class X, we say that we have **created an instance of the class X**.
# * In the code, above we created an instance of the class Jedi.

# %% [markdown]
# # 2.How to define a class in Python

# %%
# **Python File: jedi_class.py**

# 1. Where we define the class
class Jedi:
    
    # The constructor is automatically called.
    # every time time a new instance of the class is created.
    def __init__(self, name):
        self.jedi_name = name


    # Adding functions to the class
    def say_hi(self):
        print('Hello, my name is ', self.jedi_name)


#2. Definition to create and use variables(Instance) of type Jedi

j1 = Jedi('ObiWan')
j1.say_hi()

j2 = Jedi('Anakin')
j2.say_hi()
# Out:
# Hello, my name is  ObiWan
# Hello, my name is  Anakin

# %% [markdown]
# The code above has two parts:
#
# > 1. Where we define the class
# >
# >2. Where we use the definition to create and use variables of type Jedi (j1 and j2)

# %% [markdown]
# ### **2.1 Definition of a class**
#
# The first thing that we see is the tag class and the name Jedi.

# %%
class Jedi:

# %% [markdown]
# Let's see the different parts that can contain a class.
#
#
# ### **2.2 Functions of the class**
#
# * Then, we continue with the tag **def**.
# * As you know from the previous chapter, that means that what follows is the definition of a function.
# *However, in this case, the function is just defined for the class **Jedi** because, as you can see, it has an indentation within the class.

# %%
def __init__(self,name):
def say_hi(self):

# %% [markdown]
# **Note** that each of the functions contain the **self** keyword as a parameter.
# > * That keyword indicates that **the functions belong to the class**.
# > * Including the **self** keyword is **mandatory for each function of the class.**
#
# **What does it mean that a function is only of the class?**
#
# > * It means that you can only call that function through an **instance of the class**.
# > * That is, you cannot call the function *say_hi()* in your programs by doing:

# %%
say_hi()

# %% [markdown]
# **In order to call that function**, you need to
#
# > 1. First create an instance of the class **Jedi** and
# > 2. then **call the function**. Like this:

# %%
j = Jedi()
j.say_hi()

# %% [markdown]
# ### **2.3 The class constructor**
#
# From the two functions defined above, there is one that is very special and that is called the **constructor of the class**. That function is the following:

# %%
def __init__(self, name):
    self.jedi_name = name

# %% [markdown]
# For any class that you create (the Jedi class, the RobotControl class, or any other that you may invent), the function named __ **init** __ is called the **constructor of the class**.
#
# What is special about the constructor?
#
# > **The constructor is automatically called (by the Python system) every time that a new instance of the class is created.**
#
# For example, when we created the instance of the Jedi class, the __ **init** __(self, name) function was called.
# > * As you know from previous chapters, the parameter name is provided to the constructor.
# > * So, the constructor uses that parameter to store it in the variable self.jedi_name.
#
#
# The constructor of a class is a very important function because it is the one that is used to initialize the class with the proper values, based on the parameters provided. For example, in the code above:

# %%
j1 = Jedi('ObiWan')

# %% [markdown]
# We are creating an instance of the class Jedi, providing to it the parameter ObiWan.
#
# > 1. That is used by the  __ **init** __  function of the Jedi class (the constructor of the Jedi class) to initialize that self.jedi_name variable.
# > 2. That is the only thing that we do in the constructor, but we could add anything else required to have the Jedi instance properly configured.
#
# ### **Variables of the class**
#
#
# A class usually has variables inside to store proper values for every instance. Those variables allow differentiation of every instance of the same class from each other.
#
# > For example, in the code above, the class Jedi has a variable of the class named self.jedi_name.
#
# > That variable must contain the name of the Jedi for each instance of the class.
#
# That is why, later in the code, we have:

# %%
j1 = Jedi('ObiWan')
j2 = Jedi('Anakin')

# %% [markdown]
# > The value of self.jedi_name for j1 is ObiWan,
# >
# > but the value of self.jedi_name for j2 is Anakin.
#
#  **You can create as many instances(variables)** of a class as you want, but each one has a different value in their class parameters.
#
# **IMPORTANT**: To create a variable of a class, it always has to start by the prefix self. and then the variable name.
#
# > **REMEMBER** to add that **self. prefix** on any place of the class.

# %%
self.jedi_name = name

# %% [markdown]
# **Variables of the class are like global variables for that class!**
#
# What does that mean?
# > It means that the variables can be used in any function that belongs to the class, like when we were using the global keyword in Unit 4.
#
# **IMPORTANT 2:** This is one of the main points of using classes.
# > * You will not have to use global variables that can be accessed in any part of the code, contributing to the building of a mess.
# > *  By **encapsulating** the variables within the class, only the functions of the class can access those variables, hence, you have less chance of messing it up.

# %% [markdown]
# **IMPORTANT 3: From now on, you cannot use the global keyword in your programs. That is a very bad practice!!!**
# > **Instead, you should organize your Python program to use classes that do not need global variables (instead, they use the variables of the class).**

# %% [markdown]
# ### **2.4 Adding functions to the class**
#
# Apart from the constructor of the class, you can define any other function that you need to make your class useful. For example, in the class Jedi, there is an extra function named say_hi(), which makes the class print a hello message.

# %%
def say_hi(self):
        print('Hello, my name is', self.jedi_name)

# %% [markdown]
# This is another function of the class. In this case, it just contains a simple print inside which takes into account the value of the variable self.jedi_name.
#
#
# **IMPORTANT**: As you can see in the function *say_hi()*, the function can access the variable of the *class self.jedi_name*,
# >  without having to use the global keyword, because the *self.jedi_name* is a variable of the class, hence it can be accessed by any function of the class.
#
# **NOTE**: The functions of the class can modify any variable of the class!
# > They can access those values for reading or even for modifying the values.

# %% [markdown]
# ### **2.5 Calling a class function**
#
#
# * As explained above, in order to call a function that belongs to the class, you need to first create an instance of the class.
# * This allows you to have different instances of the class, that, when calling any of its member functions, will produce different results.
#
# For example, in the code above, we have the following code:

# %%
j1 = Jedi('ObiWan')
j1.say_hi()

j2 = Jedi('Anakin')
j2.say_hi()
# Out:
# Hello, my name is  ObiWan
# Hello, my name is  Anakin

# %% [markdown]
# This means that we are creating **two different instances of the same class Jedi**. Each instance is about a different Jedi.
# > * Hence, calling the say_hi() function for each instance will produce different results.

# %% [markdown]
# ## **Exercise 5.1**
#
# Create a Python program that makes the robot perform 2 squares. The second one will be double the size of the first one.
#
#
# ALL the parameters that you need to pass to the functions in order to control the robot (**motion, clockwise, speed, time, and maybe other**s) will have to be declared as **attributes** of the class.
#
# You will need to:
#
# > 1. Import the RobotControl class.
# 2. Use the *move_straight_time()* and *turn()* functions of that class.
# 3. Create the constructor of your class.
# 4. Create the necessary functions of your class, in order to perform a square.
# 5. Create 2 different instances of the class, one for each square movement.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# test_class.py

from robot_control_class import RobotControl

# 1. Define class 
class MoveRobot:

  # 2.Contructor  
    def __init__(self, motion, clockwise, speed, time):
       
  # 2.1 function variable define , other class variable 
        self.robotcontrol = RobotControl()

  # 2.1 function variable define 
        self.motion = motion
        self.clockwise = clockwise
        self.speed = speed
        self.time = time
        self.time_turn = 7.0 # This is an estimate time in which the robot will rotate 90 degrees


  # 2. Define function 
    def move_straight(self):
        self.robotcontrol.move_straight_time(self.motion, self.speed, self.time)

    def turn(self):
        self.robotcontrol.turn(self.clockwise, self.speed, self.time_turn)

  # 3. Define Algorithm 
    def do_square(self):

        i = 0

        while (i < 4):
            self.move_straight()
            self.turn()
            i+=1


mr1 = MoveRobot('forward', 'clockwise', 0.3, 4)
mr1.do_square()
mr2 = MoveRobot('forward', 'clockwise', 0.3, 8)
mr2.do_square()

# %% [markdown]
# # 3 How the class RobotControl works
#
# Now that you are equipped with all the knowledge to write your own Python programs, it is time for you to check the RobotControl class that you have been using throughout the whole course!

# %%
# robot_control_class.py

#!/usr/bin/env python

import rospy
from geometry_msgs.msg import Twist
from sensor_msgs.msg import LaserScan
import time

# 1. Calss Define 
class RobotControl():

    # 2.Contructor
    def __init__(self):

        rospy.init_node('robot_control_node', anonymous=True)
        self.vel_publisher = rospy.Publisher('/cmd_vel', Twist, queue_size=1)

        self.laser_subscriber = rospy.Subscriber(
            '/kobuki/laser/scan', LaserScan, self.laser_callback)
        self.summit_laser_subscriber = rospy.Subscriber(
            '/hokuyo_base/scan', LaserScan, self.summit_laser_callback)
        
        self.cmd = Twist()
        self.laser_msg = LaserScan()
        self.summit_laser_msg = LaserScan()
        
        self.ctrl_c = False
        self.rate = rospy.Rate(1)
        rospy.on_shutdown(self.shutdownhook)

    def publish_once_in_cmd_vel(self):
        """
        This is because publishing in topics sometimes fails the first time you publish.
        In continuous publishing systems, this is no big deal, but in systems that publish only
        once, it IS very important.
        """
        while not self.ctrl_c:
            connections = self.vel_publisher.get_num_connections()
            if connections > 0:
                self.vel_publisher.publish(self.cmd)
                #rospy.loginfo("Cmd Published")
                break
            else:
                self.rate.sleep()

    def shutdownhook(self):
        # works better than the rospy.is_shutdown()
        self.ctrl_c = True

    def laser_callback(self, msg):
        self.laser_msg = msg

    def summit_laser_callback(self, msg):
        self.summit_laser_msg = msg

    def get_laser(self, pos):
        time.sleep(1)
        return self.laser_msg.ranges[pos]

    def get_laser_summit(self, pos):
        time.sleep(1)
        return self.summit_laser_msg.ranges[pos]

    def get_front_laser(self):
        time.sleep(1)
        return self.laser_msg.ranges[360]

    def get_laser_full(self):
        time.sleep(1)
        return self.laser_msg.ranges

    def stop_robot(self):
        #rospy.loginfo("shutdown time! Stop the robot")
        self.cmd.linear.x = 0.0
        self.cmd.angular.z = 0.0
        self.publish_once_in_cmd_vel()

    def move_straight(self):

        # Initilize velocities
        self.cmd.linear.x = 0.5
        self.cmd.linear.y = 0
        self.cmd.linear.z = 0
        self.cmd.angular.x = 0
        self.cmd.angular.y = 0
        self.cmd.angular.z = 0

        # Publish the velocity
        self.publish_once_in_cmd_vel()

    def move_straight_time(self, motion, speed, time):

        # Initilize velocities
        self.cmd.linear.y = 0
        self.cmd.linear.z = 0
        self.cmd.angular.x = 0
        self.cmd.angular.y = 0
        self.cmd.angular.z = 0

        if motion == "forward":
            self.cmd.linear.x = speed
        elif motion == "backward":
            self.cmd.linear.x = - speed

        i = 0
        # loop to publish the velocity estimate, current_distance = velocity * (t1 - t0)
        while (i <= time):

            # Publish the velocity
            self.vel_publisher.publish(self.cmd)
            i += 1
            self.rate.sleep()

        # set velocity to zero to stop the robot
        self.stop_robot()

        s = "Moved robot " + motion + " for " + str(time) + " seconds"
        return s


    def turn(self, clockwise, speed, time):

        # Initilize velocities
        self.cmd.linear.x = 0
        self.cmd.linear.y = 0
        self.cmd.linear.z = 0
        self.cmd.angular.x = 0
        self.cmd.angular.y = 0

        if clockwise == "clockwise":
            self.cmd.angular.z = -speed
        else:
            self.cmd.angular.z = speed

        i = 0
        # loop to publish the velocity estimate, current_distance = velocity * (t1 - t0)
        while (i <= time):

            # Publish the velocity
            self.vel_publisher.publish(self.cmd)
            i += 1
            self.rate.sleep()

        # set velocity to zero to stop the robot
        self.stop_robot()

        s = "Turned robot " + clockwise + " for " + str(time) + " seconds"
        return s


if __name__ == '__main__':
    
    robotcontrol_object = RobotControl()
    try:
        robotcontrol_object.move_straight()

    except rospy.ROSInterruptException:
        pass

# %% [markdown]
# ## Code Explanation
#
# First of all, let me point out that, within this class, some ROS concepts are already introduced. This might be a little confusing to you right now, at least until you take the ROS Basics in 5 Days Course.
# > * Anyway, at this point, you should be able to fully understand the different parts of the class and its main structure.
#
# First of all, we find all the imports here:

# %%
import rospy
from geometry_msgs.msg import Twist
from sensor_msgs.msg import LaserScan
import time

# %% [markdown]
# As you already learnt in Unit 2, imports allow you to include in your program the code created in other Python modules.
# > *  In this case, we are importing some ROS-related modules that we will use, and also the time module, which you have already used in previous lessons.
#
# Next, we can see the definition of the class.

# %%
class RobotControl():

# %% [markdown]
# Nothing new here. We are defining a class, named RobotControl, which doesn't take any argument.
#
# Let's keep going!
#
# > Now we can see the __ **init** __ function, also know as constructor, as you already know.

# %%
def __init__(self):
    rospy.init_node('robot_control_node', anonymous=True)
    self.vel_publisher = rospy.Publisher('/cmd_vel', Twist, queue_size=1)
    self.laser_subscriber = rospy.Subscriber(
        '/kobuki/laser/scan', LaserScan, self.laser_callback)
    self.summit_laser_subscriber = rospy.Subscriber(
        '/hokuyo_base/scan', LaserScan, self.summit_laser_callback)
    self.cmd = Twist()
    self.laser_msg = LaserScan()
    self.summit_laser_msg = LaserScan()
    self.ctrl_c = False
    self.rate = rospy.Rate(1)
    rospy.on_shutdown(self.shutdownhook)

# %% [markdown]
# Inside the constructor of the class, we are initializing and defining many different ROS elements, so we are going to ignore this part for now.
# > * Just keep in mind that here we are doing all the setup in order to be able to communicate with the simulated robot.
#
# Do you know what comes next? Yes! It's the functions of the class. For this class, we have many of them.
# > * Most of them, though, might already sound familiar to you since you have been using them all along in this course.
#
# For instance, you can see all the laser functions, which have allowed you to get the laser readings from the robots:

# %%
def get_laser(self, pos):
    time.sleep(1)
    return self.laser_msg.ranges[pos]

def get_laser_summit(self, pos):
    time.sleep(1)
    return self.summit_laser_msg.ranges[pos]

def get_front_laser(self):
    time.sleep(1)
    return self.laser_msg.ranges[360]

def get_laser_full(self):
    time.sleep(1)
    return self.laser_msg.ranges

# %% [markdown]
# Or also the different functions that you have been using in order to move the robots around:

# %%
def stop_robot(self):
    #rospy.loginfo("shutdown time! Stop the robot")
    self.cmd.linear.x = 0.0
    self.cmd.angular.z = 0.0
    self.publish_once_in_cmd_vel()

def move_straight(self):

    # Initilize velocities
    self.cmd.linear.x = 0.5
    self.cmd.linear.y = 0
    self.cmd.linear.z = 0
    self.cmd.angular.x = 0
    self.cmd.angular.y = 0
    self.cmd.angular.z = 0

    # Publish the velocity
    self.publish_once_in_cmd_vel()

def move_straight_time(self, motion, speed, time):

    # Initilize velocities
    self.cmd.linear.y = 0
    self.cmd.linear.z = 0
    self.cmd.angular.x = 0
    self.cmd.angular.y = 0
    self.cmd.angular.z = 0

    if motion == "forward":
        self.cmd.linear.x = speed
    elif motion == "backward":
        self.cmd.linear.x = - speed

    i = 0
    # loop to publish the velocity estimate, current_distance = velocity * (t1 - t0)
    while (i <= time):

        # Publish the velocity
        self.vel_publisher.publish(self.cmd)
        i += 1
        self.rate.sleep()

    # set velocity to zero to stop the robot
    self.stop_robot()

    s = "Moved robot " + motion + " for " + str(time) + " seconds"
    # s is string , adding other variables by converting into string  
    return s


def turn(self, clockwise, speed, time):

    # Initilize velocities
    self.cmd.linear.x = 0
    self.cmd.linear.y = 0
    self.cmd.linear.z = 0
    self.cmd.angular.x = 0
    self.cmd.angular.y = 0

    if clockwise == "clockwise":
        self.cmd.angular.z = -speed
    else:
        self.cmd.angular.z = speed

    i = 0
    # loop to publish the velocity estimate, current_distance = velocity * (t1 - t0)
    while (i <= time):

        # Publish the velocity
        self.vel_publisher.publish(self.cmd)
        i += 1
        self.rate.sleep()

    # set velocity to zero to stop the robot
    self.stop_robot()

    s = "Turned robot " + clockwise + " for " + str(time) + " seconds"
    return s

# %% [markdown]
# Again, most of the code you can see here is ROS related, so we are not going to enter into details.
# > But you can get the general idea, which is that the Python class RobotControl has many different functions that allow you to interact with the robot, either to get data from it (laser readings) or to send data to it (move it).
#
# ## **3.1 Finally, you can see the main function**:

# %%
if __name__ == '__main__':

    robotcontrol_object = RobotControl()
    try:
        robotcontrol_object.move_straight()

    except rospy.ROSInterruptException:
        pass

# %% [markdown]
# For our course, this piece of code is not very important because we are not going to use it.
#
# >  But... what if you try to execute this file directly? Let's say, with the following command:

# %%
python robot_control_class.py

# %% [markdown]
# In this case, the main function would be executed.
# >  Ignoring the ROSInterruptException part, what you have inside this function is pretty simple (and familiar).

# %%
robotcontrol_object = RobotControl()
robotcontrol_object.move_straight()

# %% [markdown]
# As you can see, all you are doing here is creating an instance of the RobotControl() class in the robotcontrol_object variable. And then, you call the function move_straight() of this class.
#
# So, applying this to the Jedi class, for instance, it would result in something like this:

# %%
#**Python File: jedi_class.py (UPDATED)

class Jedi:
    def __init__(self, name):
        self.jedi_name = name

    def say_hi(self):
        print('Hello, my name is ', self.jedi_name)
        
if __name__ == '__main__':

    j1 = Jedi('ObiWan')
    j1.say_hi()

    j2 = Jedi('Anakin')
    j2.say_hi()
# Out:
# Hello, my name is  ObiWan
# Hello, my name is  Anakin
